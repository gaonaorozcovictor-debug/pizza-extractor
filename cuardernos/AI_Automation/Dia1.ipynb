# %% [markdown]
# # AI_Automation
# **Programa:** Big Data+ 2026-2027
# **Profesor:Cristian**
# **Tramo del curso:Inicio**
#
# ---
# Cuaderno de apuntes y práctica. Cada sesión de clase se añade como una nueva sección más abajo, siguiendo siempre la misma estructura: Fecha/Tema → Apuntes → Práctica → Dudas para repasar.

# %% [markdown]
# ## 📅 Sesión — 07/09/2026
# **Tema:** Introducción a LLMs
#
#
#
# ### Apuntes
# - ¿Qué es un LLM (Large Language Model)?
# Es el motor de la IA, se encarga de generar textos prediciendo cosas con probabilidad
#
# - ¿Cómo genera texto?
# Mediante tokens
#
# - ¿Qué es un token?
# Es una unidad de texto (puede ser una palabra completa, parte de una palabra, o un signo de puntuación) — no sigue las sílabas del idioma, lo decide el tokenizador del modelo
#
# - ¿Para qué sirve la temperatura?
# Para darle más peso a unas palabras. (Si está en 0 va a usar la más probable)

# %%
# Práctica / ejercicios de la sesión

# %% [markdown]
# ### ❓ Dudas / para repasar
# - Mirar el error de ayer(creo que es por las credenciales)
# - Dejar mas claro el concepto de token

# %% [markdown]
# ---
# ## 📅 Sesión — DD/MM/AAAA
# **Tema:**
#
# ### Apuntes
# -
# -
# -

# %%
# Práctica / ejercicios de la sesión

# %% [markdown]
# ### ❓ Dudas / para repasar
# -

# %% [markdown]
# ---
# ## 🔁 Repaso semanal (miércoles/jueves)
# **Semana del:**
#
# ### Qué repasé
# -
#
# ### Dudas resueltas
# -
#
# ### Sigo con dudas en
# -
